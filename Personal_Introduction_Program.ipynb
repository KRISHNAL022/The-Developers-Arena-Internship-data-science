# %% [markdown]
# # 1. Write your first 'Hello World' program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. Create variables to store your personal information

# %%
name = "Krishna"
age = 20
city = "Pune"

print(name, age, city)
# Out:
# Krishna 20 Pune

# %% [markdown]
# 3. Practice basic math calculations in Python

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Power:", a ** b)
print("Modulus (Remainder):", a % b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Power: 100000
# Modulus (Remainder): 0

# %% [markdown]
# 4. Create a list of your favorite foods and access them

# %%
favorite_foods = ["Pizza", "Pav Bhaji", "Biriyani", "Dosa"]

print(favorite_foods[0])   # First item
print(favorite_foods[-1])  # Last item
print(favorite_foods[1:3]) # Slice of the list
# Out:
# Pizza
# Dosa
# ['Pav Bhaji', 'Biriyani']

# %% [markdown]
# 5. Build a simple bio-data program

# %%
name = "Krishna"
age = 20
city = "Pune"
favorite_foods = ["Pizza", "Pav Bhaji", "Biriyani"]

print("---- BIO DATA ----")
print("Name:", name)
print("Age:", age)
print("City:", city)
print("Favorite Foods:", ", ".join(favorite_foods))
# Out:
# ---- BIO DATA ----
# Name: Krishna
# Age: 20
# City: Pune
# Favorite Foods: Pizza, Pav Bhaji, Biriyani

# %% [markdown]
# Project:
# Create a Personal Introduction Program that asks for user's name, age, and hobby, then displays a friendly welcome message with their information

# %%
# Personal Introduction Program

name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your hobby: ")

print("\n--- Welcome Message ---")
print(f"Hello {name}! 😊")
print(f"You are {age} years old and you enjoy {hobby}.")
print("Nice to meet you!")
# Out:
# Enter your name: Krishna
# Enter your age: 20
# Enter your hobby: swimming
#
# --- Welcome Message ---
# Hello Krishna! 😊
# You are 20 years old and you enjoy swimming.
# Nice to meet you!
